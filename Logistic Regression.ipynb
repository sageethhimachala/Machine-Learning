# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("sample.csv")
data.tail()
# Out:
#     age  job
# 21   13    0
# 22   51    1
# 23   43    1
# 24   23    0
# 25   31    1

# %%
plt.scatter(data.age, data.job)

# %%
x = data[["age"]]
x
# Out:
#     age
# 0    16
# 1    24
# 2    31
# 3    29
# 4    40
# 5    33
# 6    18
# 7    36
# 8    15
# 9    37
# 10   19
# 11   21
# 12   29
# 13   31
# 14   23
# 15   20
# 16   34
# 17   22
# 18   32
# 19   15
# 20   14
# 21   13
# 22   51
# 23   43
# 24   23
# 25   31

# %%
y = data["job"]
y
# Out:
# 0     0
# 1     0
# 2     1
# 3     0
# 4     1
# 5     0
# 6     0
# 7     1
# 8     0
# 9     1
# 10    0
# 11    0
# 12    1
# 13    1
# 14    1
# 15    0
# 16    1
# 17    0
# 18    1
# 19    0
# 20    0
# 21    0
# 22    1
# 23    1
# 24    0
# 25    1
# Name: job, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
x_train
# Out:
#     age
# 17   22
# 5    33
# 20   14
# 0    16
# 13   31
# 25   31
# 3    29
# 8    15
# 14   23
# 4    40
# 16   34
# 19   15
# 6    18
# 9    37
# 21   13
# 24   23
# 11   21
# 7    36
# 22   51
# 1    24

# %%
len(x_train)
# Out:
# 20

# %%
len(x_test)
# Out:
# 6

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
model.predict(x_test)
# Out:
# array([0, 0, 1, 1, 1, 1], dtype=int64)

# %%
x_test
# Out:
#     age
# 10   19
# 15   20
# 23   43
# 2    31
# 12   29
# 18   32

# %%
y_test
# Out:
# 10    0
# 15    0
# 23    1
# 2     1
# 12    1
# 18    1
# Name: job, dtype: int64

# %%
model.score(x_test, y_test)
# Out:
# 1.0

# %%
age = [[30]]
model.predict(age)
# Out:
# C:\Users\sagee\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)

# %%
ages = np.array([[31],[22],[34]])
model.predict(ages)
# Out:
# C:\Users\sagee\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1, 0, 1], dtype=int64)
